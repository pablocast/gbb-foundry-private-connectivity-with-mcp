# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
import os, sys
sys.path.insert(1, '../src')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
utils.cleanup_resources(deployment_name)
# Out:
# 👉🏽 🧹 Cleaning up resource group 'lab-notebooks'...
# ⚙️ Running: az deployment group show --name notebooks -g lab-notebooks -o json
# ✅ Deployment retrieved ⌚ 10:54:40.875091 :5s]
# 👉🏽 Deployment provisioning state: Failed
# ⚙️ Running: az resource list -g lab-notebooks --resource-type "microsoft.cognitiveservices/accounts/projects"
# ✅ Retrieved AI Foundry projects ⌚ 10:54:45.214210 :4s]
# ⚙️ Running: az cognitiveservices account list -g lab-notebooks
# ✅ Listed CognitiveService accounts ⌚ 10:54:49.209039 :3s]
# 👉🏽 Deleting and purging Cognitive Service Account 'openai1-orileqqs2tzlo' in resource group 'lab-notebooks'...
# ⚙️ Running: az cognitiveservices account delete -g lab-notebooks -n openai1-orileqqs2tzlo
# ✅ Cognitive Services 'openai1-orileqqs2tzlo' deleted ⌚ 10:54:55.173990 :5s]
# ⚙️ Running: az cognitiveservices account purge -g lab-notebooks -n openai1-orileqqs2tzlo -l "eastus"
# ✅ Cognitive Services 'openai1-orileqqs2tzlo' purged ⌚ 10:55:01.078023 :5s]
# ⚙️ Running:  az apim list -g lab-notebooks
# ✅ Listed APIM resources ⌚ 10:55:05.242667 :4s]
# 👉🏽 Deleting and purging API Management 'apim-orileqqs2tzlo' in resource group 'lab-notebooks'...
# ⚙️ Running: az apim delete -n apim-orileqqs2tzlo -g lab-notebooks -y
# ✅ API Management 'apim-orileqqs2tzlo' deleted ⌚ 10:56:10.549444 :5s]
# ⚙️ Running: az apim deletedservice purge --service-name apim-orileqqs2tzlo --location "East US 2"
# ✅ API Management 'apim-orileqqs2tzlo' purged ⌚ 10:57:41.926555 :31s]
# ⚙️ Running: az keyvault list -g lab-notebooks
# ✅ Listed Key Vault resources ⌚ 10:57:48.244378 :6s]
# 👉🏽 🧹 Deleting resource group 'lab-notebooks'... ⌚ 10:57:48.244928
# ⚙️ Running: az group delete --name lab-notebooks -y
# ✅ Resource group 'lab-notebooks' deleted ⌚ 11:37:02.385844 :14s]
# 👉🏽 🧹 Cleanup completed. ⌚ 11:37:02.389030
